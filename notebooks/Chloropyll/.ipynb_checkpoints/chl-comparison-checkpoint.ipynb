# %% [markdown]
# ### Comparing chlorophull-a concentration extimates for Trocas expeditions in the Amazon mouth
#
# - I used find and replace in LibreOffice to remove all the Portuguese accents from the Excel final, and then I saved the first tab as a `csv` so I could easily read into Python.

# %%
import os
os.chdir("/home/millieginty/Documents/git-repos/amazon//")

# %%
import pandas as pd
import numpy as np

# Load INPE fluorometer data sent by Aline in Dec 2023
# There's a copy of the Excel file in my manuscripts directory

fluor_data = pd.read_csv("data/chlorophyll/HPLCandFluorChlaT1toT8.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load INPE fluorometer data sent by Aline in Dec 2023
# There's a copy of the Excel file in my manuscripts directory
fluor_data = pd.read_csv("data/chlorophyll/HPLCandFluorChlaT1toT8.csv")

# Define the rivers to plot
rivers_to_plot = ['MNL', 'MNC', 'MNR', 'MSL', 'MSC', 'MSR', 'MSUW', 'MNUW', 'BAI', 'CH']

# Filter data for each river and plot
fig, axs = plt.subplots(len(rivers_to_plot), figsize=(10, 20), sharex=True)

for i, river in enumerate(rivers_to_plot):
    river_data = fluor_data[fluor_data['RIVER'].str.startswith(river)]
    axs[i].bar(river_data.index, river_data['CHLA-FLUOR'], color='blue')  # Assuming 'CHLA-FLUOR' is the column with chlorophyll data
    axs[i].set_title(river)
    axs[i].set_ylabel('Chlorophyll (mg/L)')

plt.xlabel('Sample Index')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load INPE fluorometer data sent by Aline in Dec 2023
# There's a copy of the Excel file in my manuscripts directory
fluor_data = pd.read_csv("data/chlorophyll/HPLCandFluorChlaT1toT8.csv")

# Convert 'DATE' column to datetime
fluor_data['DATE'] = pd.to_datetime(fluor_data['DATE'])

# Sort data by date
fluor_data.sort_values(by='DATE', inplace=True)

# Define the rivers to plot
rivers_to_plot = ['MNL', 'MNC', 'MNR', 'MSL', 'MSC', 'MSR', 'MSUW', 'MNUW', 'BAI', 'CH']

# Filter data for each river and plot
fig, axs = plt.subplots(len(rivers_to_plot), figsize=(10, 20), sharex=True, sharey=True)

for i, river in enumerate(rivers_to_plot):
    river_data = fluor_data[fluor_data['RIVER'].str.startswith(river)]
    # Create index using only month and day
    river_data.index = river_data['DATE'].dt.strftime('%m-%d')
    axs[i].bar(river_data.index, river_data['CHLA-FLUOR'], color='green')  # Change bar color to green
    axs[i].set_title(river)
    axs[i].set_ylabel('Chlorophyll (mg/L)')

plt.xlabel('Sample Date (Month-Day)')
plt.xticks(rotation=30)  # Rotate x-axis labels by 30 degrees
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load INPE fluorometer data sent by Aline in Dec 2023
# There's a copy of the Excel file in my manuscripts directory
fluor_data = pd.read_csv("data/chlorophyll/HPLCandFluorChlaT1toT8.csv")

# Convert 'DATE' column to datetime
fluor_data['DATE'] = pd.to_datetime(fluor_data['DATE'])

# Sort data by date
fluor_data.sort_values(by='DATE', inplace=True)

# Define the rivers to plot
rivers_to_plot = ['MNL', 'MNC', 'MNR', 'MSL', 'MSC', 'MSR', 'MSUW', 'MNUW', 'BAI', 'CH']
rivers_to_plot = ['MNL', 'MNC', 'MNR', 'MSL', 'MSC', 'MSR', 'BAI', 'CH']

# Filter data for each river and plot
fig, axs = plt.subplots(len(rivers_to_plot), figsize=(10, 20), sharex=True, sharey=True)

for i, river in enumerate(rivers_to_plot):
    river_data = fluor_data[fluor_data['RIVER'].str.startswith(river)]
    axs[i].bar(river_data['DATE'], river_data['CHLA-FLUOR'], color='green')  # Change bar color to green
    axs[i].set_title(river)
    axs[i].set_ylabel('Chlorophyll (mg/L)')

plt.xlabel('Sample Date')
plt.xticks(rotation=30)  # Rotate x-axis labels by 30 degrees
plt.tight_layout()
plt.show()

# %%
fluor_data.head(-10)
# Out:
#        N  TROCAS SEASON TYPE RIVER RIVER2     STATION  \
# 0      1       1      H    A    OR      O        1T01
# 1      2       1      H    A    OL      O        1T02
# 2      3       1      H    A    OC      O        1T03
# 3      4       1      H    O     T      T        1T04
# 4      5       1      H    A    AC      A        1T05
# ..   ...     ...    ...  ...   ...    ...         ...
# 173  174       7      H    A   MNR     MN    T7UCNMD1
# 174  175       7      H    A   MNC     MN  T7UCNMEIO1
# 175  176       7      H    A   MNL     MN    T7UCNME1
# 176  177       8      L    A   MNC     MN          1A
# 177  178       8      L    A   BAI    BAI           2
#
#                            Name TROCAS       DATE             LATITUDE  \
# 0     Obidos Margem Direita Superficie 2014-05-01               -1.958
# 1    Obidos Margem Esquerda Superficie 2014-05-01              -1.9402
# 2               Obidos Meio Superficie 2014-05-01              -1.9461
# 3              Tapajos meio superficie 2014-05-02               -2.459
# 4              Almerim Meio Superficie 2014-05-04              -1.5702
# ..                                 ...        ...                  ...
# 173                                NaN 2019-04-10             -0.09125
# 174                                NaN 2019-04-10  -0.0719666666666667
# 175                                NaN 2019-04-10  -0.0559833333333333
# 176                                NaN 2019-11-07              0.44373
# 177                Bailique Superficie 2019-11-08              0.77197
#
#      LONGITUDE  CHLA-HPLC  CHLA-FLUOR  TEMP     PH  TSM (mg/L)
# 0   -55.481100      0.448    0.885662  28.9  6.600         NaN
# 1   -55.486500      0.769    1.410758  29.1  6.620         NaN
# 2   -55.494500      0.415    0.856490  28.8  6.600         NaN
# 3   -55.006000     22.966   31.298833  29.7  6.460    5.496667
# 4   -52.631800      0.651    1.095700  28.9  6.680   54.540333
# ..         ...        ...         ...   ...    ...         ...
# 173 -51.007400        NaN    1.136367   NaN    NaN         NaN
# 174 -51.041317        NaN    1.035606   NaN    NaN         NaN
# 175 -51.061483        NaN    0.997755   NaN    NaN         NaN
# 176  50.563550        NaN    2.242601   NaN    NaN         NaN
# 177  50.033780        NaN    1.776578  30.1  6.862         NaN
#
# [178 rows x 16 columns]
