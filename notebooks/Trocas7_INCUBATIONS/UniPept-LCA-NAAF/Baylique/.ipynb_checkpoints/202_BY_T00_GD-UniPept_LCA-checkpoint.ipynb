# %% [markdown]
# ### Sorting and visualizing UniPept lowest common ancestor analyses in Trocas7
#
# #### Beginning with: LCA peptides in csvs
#
# #### Goal: spectral abundance-corrected (NAAF) taxonomic peptide compositions at the 4 stations before and after 24hrs
#
# ## Issue: the `join` commands at the end for diatom and bacterial peptides need to be run independently from one another. To do this, run the diatom command, restart the kernal, then run the bacterial.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
cd /home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/
# Out:
# /home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept

# %%
# read the data into pandas dataframes
BY_T00_GD_202a = pd.read_csv("lca/cleaned/202_BY_T00_GD_lca.csv")

# delete any Metazoa hits because they're trypsin
BY_T00_GD_202b = BY_T00_GD_202a[BY_T00_GD_202a.kingdom != 'Metazoa']

# keep only entries to the phylum level
BY_T00_GD_202 = BY_T00_GD_202b[BY_T00_GD_202b['phylum'].notnull()]

# How many peptides to the phylum level?
print('# of phylum peptides = ', len(BY_T00_GD_202))

BY_T00_GD_202.head(6)
# Out:
# # of phylum peptides =  10
#           peptide                             lca superkingdom kingdom  \
# 4        LATVLSPR             Gammaproteobacteria     Bacteria     NaN
# 7        VATVSPLR            Solirubrobacteraceae     Bacteria     NaN
# 11       QEFLNAAK  Phorcysia thermohydrogeniphila     Bacteria     NaN
# 31       LSVNLNSK          Listeria monocytogenes     Bacteria     NaN
# 132  VTNAELAEVLAR                Escherichia coli     Bacteria     NaN
# 191      DFQPLLLK           Bacillus obstructivus     Bacteria     NaN
#
#      subkingdom  superphylum          phylum subphylum superclass  \
# 4           NaN          NaN  Proteobacteria       NaN        NaN
# 7           NaN          NaN  Actinobacteria       NaN        NaN
# 11          NaN          NaN       Aquificae       NaN        NaN
# 31          NaN          NaN      Firmicutes       NaN        NaN
# 132         NaN          NaN  Proteobacteria       NaN        NaN
# ...

# %% [markdown]
# ### Now I want to read in the file containing the stripped peptides with NAAF values
# ####  - NAAF stands for 'noramlized area abunace factor'
#
# ### I want to join the dataframes if they share an index (stripped peptide with equated leucine and isoleucines)
# #### - That means I'll reindex the processed peptide file

# %%
BY_T00_GD_202_NAAFa = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/data/Trocas7-incubations/processed/I-L_NAAFs/202_BY_T00_GD_DN50_ILnaafs.csv")
BY_T00_GD_202_NAAFb = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/data/Trocas7-incubations/processed/I-L_NAAFs/202B_BY_T00_GD_DN50_ILnaafs.csv")
#BY_T00_GD_202_NAAFc = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/data/Trocas7-incubations/processed/I-L_NAAFs/202C_BY_T00_GD_DN50_ILnaafs.csv")


frames = [BY_T00_GD_202_NAAFa, BY_T00_GD_202_NAAFb]

BY_T00_GD_202_NAAF = pd.concat(frames, sort=False)

BY_T00_GD_202_NAAF.set_index('stripped_peptide')
BY_T00_GD_202_NAAF = BY_T00_GD_202_NAAF.loc[:, ~BY_T00_GD_202_NAAF.columns.str.contains('^Unnamed')]

BY_T00_GD_202_NAAF.rename(columns = {'stripped_peptide':'peptide'}, inplace = True)

print('# of total peptides = ', len(BY_T00_GD_202_NAAF))

print('column names:', BY_T00_GD_202_NAAF.columns)

BY_T00_GD_202_NAAF.head()
# Out:
# # of total peptides =  264
# column names: Index(['peptide', 'Area', 'NAAF_num.'], dtype='object')
#          peptide        Area     NAAF_num.
# 0  VLEGNEQFLNAAK    375000.0  2.884615e+04
# 1     LSSPATLNSR  91500000.0  9.150000e+06
# 2     LSSPATLNSR  91500000.0  9.150000e+06
# 3     LSSPATLDSR    737000.0  7.370000e+04
# 4     LSSPATLNSR  91500000.0  9.150000e+06

# %%
# get the intersection of the phylum peptides and corresponding peptides w/ NAAFs

over = np.intersect1d(BY_T00_GD_202["peptide"], BY_T00_GD_202_NAAF["peptide"])

print(over)
# Out:
# ['LATVLSPR' 'LSVNLNSK' 'QEFLNAAK' 'VATVSPLR' 'VTNAELAEVLAR']

# %%
# join the dataframes if the peptide values are the same using 'join'
# since a couple are de novo only (more for bacteria), we won't have all the UniPept peptides overlap 

BY_T00_GD_202.set_index('peptide', inplace=True)
BY_T00_GD_202_NAAF.set_index('peptide', inplace=True)

BY_T00_GD_202_Phy = BY_T00_GD_202.join(BY_T00_GD_202_NAAF, how='left', rsuffix='_other')


print('# of total phylum-level peptides = ', len(BY_T00_GD_202_Phy))

BY_T00_GD_202_Phy.head()
# Out:
# # of total phylum-level peptides =  22
#                             lca superkingdom kingdom  subkingdom  superphylum  \
# peptide
# DFQPLLLK  Bacillus obstructivus     Bacteria     NaN         NaN          NaN
# LATVLSPR    Gammaproteobacteria     Bacteria     NaN         NaN          NaN
# LATVLSPR    Gammaproteobacteria     Bacteria     NaN         NaN          NaN
# LATVLSPR    Gammaproteobacteria     Bacteria     NaN         NaN          NaN
# LATVLSPR    Gammaproteobacteria     Bacteria     NaN         NaN          NaN
#
#                   phylum subphylum superclass                class subclass  \
# peptide
# DFQPLLLK      Firmicutes       NaN        NaN              Bacilli      NaN
# LATVLSPR  Proteobacteria       NaN        NaN  Gammaproteobacteria      NaN
# LATVLSPR  Proteobacteria       NaN        NaN  Gammaproteobacteria      NaN
# LATVLSPR  Proteobacteria       NaN        NaN  Gammaproteobacteria      NaN
# ...

# %%
# write to a csv

BY_T00_GD_202_Phy.to_csv("lca/NAAF/BY_T00_GD_202_Phy_naaf.csv")
