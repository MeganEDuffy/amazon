# %% [markdown]
# ## Evaluating and visualizing gene ontology (GO) terms associated bacterial peptides in Trocas 7 incubations
#
# #### Beginning with: stripped bacterial peptides and GO term abundances in spreadsheets
#
# #### Goal: heatmaps of GO terms over stations

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Plotting bacterial GO terms using Seaborn heatmap
#
# ### For each incubation station
# ### For all 3 classes of GO: biological process, cellular component, molecular function

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

cc = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/MS_CC_GO_sorted.csv", index_col=0)

cc.head()
# Out:
#                                 Time 0 small   T0 large  Unnamed: 3  \
# GO Cellular Component
# integral component of membrane     45.188285  46.925566         NaN
# cytoplasm                          23.012552  23.300971         NaN
# plasma membrane                    16.736402  19.093851         NaN
# nucleus                            11.297071   7.119741         NaN
# ribosome                            2.928870   1.941748         NaN
#
#                                 T24 small  Time 24 large
# GO Cellular Component
# integral component of membrane  45.116279      43.540670
# cytoplasm                       22.325581      23.923445
# plasma membrane                 20.465116      18.181818
# nucleus                          8.372093      11.483254
# ribosome                         3.255814       2.392344

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(cc, cmap="BuPu", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of cellular component GO terms: Macapa South", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of cellular component GO terms: Macapa South')

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

mf = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/MS_MF_GO_sorted.csv", index_col=0)

mf.head()
# Out:
#                          Time 0 small   T0 large  Unnamed: 3  T24 small  \
# GO Cellular Component
# ATP binding                 31.545741  31.460674         NaN  29.069767
# DNA binding                 21.135647  19.662921         NaN  21.317829
# metal ion binding           16.088328  20.224719         NaN  20.542636
# oxidoreductase activity      4.100946   5.898876         NaN   5.038760
# ATPase                       8.201893   4.775281         NaN   5.426357
#
#                          Time 24 large
# GO Cellular Component
# ATP binding                  28.740157
# DNA binding                  22.834646
# metal ion binding            18.503937
# oxidoreductase activity       5.511811
# ATPase                        5.905512

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(mf, cmap="Blues", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of molecular function GO terms: Macapa South", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of molecular function GO terms: Macapa South')
