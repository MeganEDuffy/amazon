# %% [markdown]
# ## Evaluating and visualizing gene ontology (GO) terms associated bacterial peptides in Trocas 7 incubations
#
# #### Beginning with: stripped bacterial peptides and GO term abundances in spreadsheets
#
# #### Goal: heatmaps of GO terms over stations

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Plotting bacterial GO terms using Seaborn heatmap
#
# ### For each incubation station
# ### For all 3 classes of GO: biological process, cellular component, molecular function

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

cc = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/BY_CC_GO_sorted.csv", index_col=0)

cc.head()
# Out:
#                                 Time 0 small   T0 large  Unnamed: 3  \
# GO Cellular Component
# integral component of membrane     41.520468  48.837209         NaN
# cytoplasm                          28.654971  23.255814         NaN
# plasma membrane                    18.128655  13.953488         NaN
# nucleus                             7.017544   6.976744         NaN
# ribosome                            2.339181   3.488372         NaN
#
#                                 T24 small  Time 24 large
# GO Cellular Component
# integral component of membrane  48.120301      45.360825
# cytoplasm                       22.932331      22.680412
# plasma membrane                 18.421053      19.587629
# nucleus                          6.766917       6.185567
# ribosome                         2.255639       4.123711

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(cc, cmap="BuPu", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of cellular component GO terms: Baylique", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of cellular component GO terms: Baylique')

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

mf = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/BY_MF_GO_sorted.csv", index_col=0)

mf.head()
# Out:
#                          Time 0 small   T0 large  Unnamed: 3  T24 small  \
# GO Cellular Component
# ATP binding                 32.367150  26.851852         NaN  26.300578
# DNA binding                 20.289855  23.148148         NaN  22.254335
# metal ion binding           19.806763  15.740741         NaN  21.965318
# oxidoreductase activity      5.797101   6.481481         NaN   4.046243
# ATPase                       5.797101   7.407407         NaN   4.913295
#
#                          Time 24 large
# GO Cellular Component
# ATP binding                  27.433628
# DNA binding                  25.663717
# metal ion binding            21.238938
# oxidoreductase activity       7.964602
# ATPase                        5.309735

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(mf, cmap="Blues", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of molecular function GO terms: Baylique", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of molecular function GO terms: Baylique')
