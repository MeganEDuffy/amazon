# %% [markdown]
# ## Evaluating and visualizing gene ontology (GO) terms associated bacterial peptides in Trocas 7 incubations
#
# #### Beginning with: stripped bacterial peptides and GO term abundances in spreadsheets
#
# #### Goal: heatmaps of GO terms over stations

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Plotting bacterial GO terms using Seaborn heatmap
#
# ### For each incubation station
# ### For all 3 classes of GO: biological process, cellular component, molecular function

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

cc = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/MN_CC_GO_sorted.csv", index_col=0)

cc.head()
# Out:
#                                 Time 0 small   T0 large  Unnamed: 3  \
# GO Cellular Component
# integral component of membrane     44.202899  44.516129         NaN
# cytoplasm                          29.710145  23.225806         NaN
# plasma membrane                    16.666667  21.935484         NaN
# nucleus                             7.971014   8.387097         NaN
# ribosome                            0.724638   1.935484         NaN
#
#                                 T24 small  Time 24 large
# GO Cellular Component
# integral component of membrane  43.648208      47.027027
# cytoplasm                       24.429967      21.621622
# plasma membrane                 18.892508      18.918919
# nucleus                          9.446254       9.729730
# ribosome                         2.605863       1.621622

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(cc, cmap="BuPu", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of cellular component GO terms: Macapa North", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of cellular component GO terms: Macapa North')

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

mf = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/MN_MF_GO_sorted.csv", index_col=0)

mf.head()
# Out:
#                          Time 0 small   T0 large  Unnamed: 3  T24 small  \
# GO Cellular Component
# ATP binding                 27.868852  29.444444         NaN  29.096045
# DNA binding                 19.125683  20.000000         NaN  22.881356
# metal ion binding           20.765027  18.333333         NaN  19.491525
# oxidoreductase activity      4.371585   6.666667         NaN   5.932203
# ATPase                       6.557377   6.666667         NaN   4.237288
#
#                          Time 24 large
# GO Cellular Component
# ATP binding                  27.826087
# DNA binding                  20.869565
# metal ion binding            18.260870
# oxidoreductase activity       5.652174
# ATPase                        5.217391

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(4,7))

labels = ['Time 0 small', 'Time 0 large', '', 'Time 24 small', 'Time 24 large']

ax = sns.heatmap(mf, cmap="Blues", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of GO terms in sample'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
ax.set_xticklabels(labels, rotation = 50)
    
plt.title("% of molecular function GO terms: Macapa North", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of molecular function GO terms: Macapa North')
