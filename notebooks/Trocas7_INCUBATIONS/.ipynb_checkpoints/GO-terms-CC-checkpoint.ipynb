# %% [markdown]
# ## Evaluating and visualizing gene ontology (GO) terms associated bacterial peptides in Trocas 7 incubations
#
# #### Beginning with: stripped bacterial peptides and GO term abundances in spreadsheets
#
# #### Goal: heatmaps of bacterial GO terms over the 4 timepoints

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %% [markdown]
# ## First, combining all bacterial peptides from all timepoints and treatments (trypsin digested and naturally digested) to get a hierarchy of all possible GO terms

# %%
# We want the stripped peptides of just bacterial LCA hits in UniPept.
# Navigate to where these LCA output are in csvs in git repo:

# !ls /home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/
# Out:
# T0-322-trypsin-lca-DB.csv   T12-325-trypsin-lca-DN.csv
# T0-322-trypsin-lca-DN.csv   T2-323-trypsin-lca-DN.csv
# T12-325-trypsin-lca-DB.csv  T5-324-trypsin-lca-DN.csv

# %% [markdown]
# ### 1. T0 322 trypsin PeaksDB (DB)

# %%
# read the data into pandas dataframes
T0_322_dig_DB = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T0-322-trypsin-lca-DB.csv", index_col=0)

T0_322_dig_DB.head()
# Out:
#                       lca superkingdom kingdom subkingdom superphylum phylum  \
# peptide
# LPQVEGTGGDVQPSQDLVR  root          NaN     NaN        NaN         NaN    NaN
# VLGQNEAVDAVSNALR     root          NaN     NaN        NaN         NaN    NaN
# ALDLLDEAASSLR        root          NaN     NaN        NaN         NaN    NaN
# VTDAELAEVLAR         root          NaN     NaN        NaN         NaN    NaN
# STEFDNLLLVGPLAGK      NaN          NaN     NaN        NaN         NaN    NaN
#
#                     subphylum superclass class subclass  ... tribe subtribe  \
# peptide                                                  ...
# LPQVEGTGGDVQPSQDLVR       NaN        NaN   NaN      NaN  ...   NaN      NaN
# VLGQNEAVDAVSNALR          NaN        NaN   NaN      NaN  ...   NaN      NaN
# ALDLLDEAASSLR             NaN        NaN   NaN      NaN  ...   NaN      NaN
# VTDAELAEVLAR              NaN        NaN   NaN      NaN  ...   NaN      NaN
# STEFDNLLLVGPLAGK          NaN        NaN   NaN      NaN  ...   NaN      NaN
#
#                     genus subgenus species group species.1 subgroup species.2  \
# peptide
# LPQVEGTGGDVQPSQDLVR   NaN      NaN     NaN   NaN       NaN      NaN       NaN
# VLGQNEAVDAVSNALR      NaN      NaN     NaN   NaN       NaN      NaN       NaN
# ALDLLDEAASSLR         NaN      NaN     NaN   NaN       NaN      NaN       NaN
# VTDAELAEVLAR          NaN      NaN     NaN   NaN       NaN      NaN       NaN
# STEFDNLLLVGPLAGK      NaN      NaN     NaN   NaN       NaN      NaN       NaN
#
#                     subspecies
# peptide
# LPQVEGTGGDVQPSQDLVR        NaN
# VLGQNEAVDAVSNALR           NaN
# ALDLLDEAASSLR              NaN
# VTDAELAEVLAR               NaN
# STEFDNLLLVGPLAGK           NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T0_322_dig_DB_Bac1 = T0_322_dig_DB.loc[(T0_322_dig_DB['kingdom'] == 'Bacteria')]

T0_322_dig_DB_Bac2 = T0_322_dig_DB.loc[(T0_322_dig_DB['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T0_322_dig_DB_Bac1))

print('# of subkingdom = ', len(T0_322_dig_DB_Bac2))

frames = [T0_322_dig_DB_Bac1, T0_322_dig_DB_Bac2]
  
T0_322_dig_DB_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T0_322_dig_DB_Bac))

T0_322_dig_DB_Bac.head()
# Out:
# # of kingdom =  8
# # of subkingdom =  1
# # of total Bacteria peptides =  9
#                        lca   superkingdom   kingdom subkingdom superphylum  \
# peptide
# QGYSNPR        Barnesiella    viscericola  Bacteria        NaN         NaN
# DSPPALALK  Verrucomicrobia      bacterium  Bacteria        NaN         NaN
# SVDPYDR       Streptomyces  violaceoruber  Bacteria        NaN         NaN
# NDEALAFLR      Chloroflexi      bacterium  Bacteria        NaN         NaN
# SGDCTQER     Myxococcaceae      bacterium  Bacteria        NaN         NaN
#
#           phylum        subphylum     superclass         class  \
# peptide
# QGYSNPR      NaN    Bacteroidetes            NaN           NaN
# DSPPALALK    NaN  Verrucomicrobia            NaN           NaN
# SVDPYDR      NaN   Actinobacteria            NaN           NaN
# NDEALAFLR    NaN      Chloroflexi            NaN           NaN
# SGDCTQER     NaN   Proteobacteria  delta/epsilon  subdivisions
#
#                  subclass  ...          tribe subtribe genus      subgenus  \
# peptide                    ...
# QGYSNPR       Bacteroidia  ...            NaN      NaN   NaN   Barnesiella
# DSPPALALK             NaN  ...            NaN      NaN   NaN           NaN
# SVDPYDR    Actinobacteria  ...            NaN      NaN   NaN  Streptomyces
# NDEALAFLR             NaN  ...            NaN      NaN   NaN           NaN
# SGDCTQER              NaN  ...  Myxococcaceae      NaN   NaN           NaN
#
#           species group species.1         subgroup      species.2 subspecies
# peptide
# QGYSNPR       NaN   NaN       NaN      Barnesiella    viscericola        NaN
# DSPPALALK     NaN   NaN       NaN  Verrucomicrobia      bacterium        NaN
# SVDPYDR       NaN   NaN       NaN     Streptomyces  violaceoruber        NaN
# NDEALAFLR     NaN   NaN       NaN      Chloroflexi      bacterium        NaN
# SGDCTQER      NaN   NaN       NaN              NaN  Myxococcaceae  bacterium
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 2. T0 322 trypsin de novo (DN)

# %%
# read the data into pandas dataframes
T0_322_dig_DN = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T0-322-trypsin-lca-DN.csv", index_col=0)

T0_322_dig_DN.head()
# Out:
#                     lca superkingdom        kingdom subkingdom superphylum  \
# peptide
# TPEEEER            root          NaN            NaN        NaN         NaN
# AAEEEEER           root          NaN            NaN        NaN         NaN
# WAEEEEER  Viridiplantae    Eukaryota  Viridiplantae        NaN         NaN
# KLPEER             root          NaN            NaN        NaN         NaN
# ESQAWSR      Tardiphaga     Bacteria            NaN        NaN         NaN
#
#                   phylum subphylum superclass                class subclass  \
# peptide
# TPEEEER              NaN       NaN        NaN                  NaN      NaN
# AAEEEEER             NaN       NaN        NaN                  NaN      NaN
# WAEEEEER             NaN       NaN        NaN                  NaN      NaN
# KLPEER               NaN       NaN        NaN                  NaN      NaN
# ESQAWSR   Proteobacteria       NaN        NaN  Alphaproteobacteria      NaN
#
#           ... tribe subtribe       genus subgenus species group species.1  \
# peptide   ...
# TPEEEER   ...   NaN      NaN         NaN      NaN     NaN   NaN       NaN
# AAEEEEER  ...   NaN      NaN         NaN      NaN     NaN   NaN       NaN
# WAEEEEER  ...   NaN      NaN         NaN      NaN     NaN   NaN       NaN
# KLPEER    ...   NaN      NaN         NaN      NaN     NaN   NaN       NaN
# ESQAWSR   ...   NaN      NaN  Tardiphaga      NaN     NaN   NaN       NaN
#
#          subgroup species.2 subspecies
# peptide
# TPEEEER       NaN       NaN        NaN
# AAEEEEER      NaN       NaN        NaN
# WAEEEEER      NaN       NaN        NaN
# KLPEER        NaN       NaN        NaN
# ESQAWSR       NaN       NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T0_322_dig_DN_Bac1 = T0_322_dig_DN.loc[(T0_322_dig_DN['kingdom'] == 'Bacteria')]

T0_322_dig_DN_Bac2 = T0_322_dig_DN.loc[(T0_322_dig_DN['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T0_322_dig_DN_Bac1))

print('# of subkingdom = ', len(T0_322_dig_DN_Bac2))

frames = [T0_322_dig_DN_Bac1, T0_322_dig_DN_Bac2]
  
T0_322_dig_DN_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T0_322_dig_DN_Bac))

T0_322_dig_DN_Bac.head()
# Out:
# # of kingdom =  100
# # of subkingdom =  5
# # of total Bacteria peptides =  105
#                       lca  superkingdom   kingdom subkingdom superphylum  \
# peptide
# FNSSLAGR      Rhodobacter       viridis  Bacteria        NaN         NaN
# WTLEEDAK        Kutzneria  buriramensis  Bacteria        NaN         NaN
# VTNAELAEVLAR  Escherichia          coli  Bacteria        NaN         NaN
# QGYSNPR       Barnesiella   viscericola  Bacteria        NaN         NaN
# VSLNKVYK        Ehrlichia    minasensis  Bacteria        NaN         NaN
#
#              phylum       subphylum superclass class             subclass  \
# peptide
# FNSSLAGR        NaN  Proteobacteria        NaN   NaN  Alphaproteobacteria
# WTLEEDAK        NaN  Actinobacteria        NaN   NaN       Actinobacteria
# VTNAELAEVLAR    NaN  Proteobacteria        NaN   NaN  Gammaproteobacteria
# QGYSNPR         NaN   Bacteroidetes        NaN   NaN          Bacteroidia
# VSLNKVYK        NaN  Proteobacteria        NaN   NaN  Alphaproteobacteria
#
#               ... tribe subtribe genus     subgenus species  group species.1  \
# peptide       ...
# FNSSLAGR      ...   NaN      NaN   NaN  Rhodobacter     NaN    NaN       NaN
# WTLEEDAK      ...   NaN      NaN   NaN    Kutzneria     NaN    NaN       NaN
# VTNAELAEVLAR  ...   NaN      NaN   NaN  Escherichia     NaN    NaN       NaN
# QGYSNPR       ...   NaN      NaN   NaN  Barnesiella     NaN    NaN       NaN
# VSLNKVYK      ...   NaN      NaN   NaN    Ehrlichia     NaN  canis     group
#
#                  subgroup     species.2  subspecies
# peptide
# FNSSLAGR      Rhodobacter       viridis         NaN
# WTLEEDAK        Kutzneria  buriramensis         NaN
# VTNAELAEVLAR  Escherichia          coli         NaN
# QGYSNPR       Barnesiella   viscericola         NaN
# VSLNKVYK              NaN     Ehrlichia  minasensis
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 3. T2 323 trypsin DN

# %%
# read the data into pandas dataframes
T2_323_dig_DN = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T2-323-trypsin-lca-DN.csv", index_col=0)

T2_323_dig_DN.head()
# Out:
#             lca superkingdom kingdom subkingdom superphylum phylum subphylum  \
# peptide
# TPEEEER    root          NaN     NaN        NaN         NaN    NaN       NaN
# HAVSEGTK   root          NaN     NaN        NaN         NaN    NaN       NaN
# KQELEDLTK  root          NaN     NaN        NaN         NaN    NaN       NaN
# TTEEAVR    root          NaN     NaN        NaN         NaN    NaN       NaN
# CLAYPK     root          NaN     NaN        NaN         NaN    NaN       NaN
#
#           superclass class subclass  ... tribe subtribe genus subgenus  \
# peptide                              ...
# TPEEEER          NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# HAVSEGTK         NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# KQELEDLTK        NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# TTEEAVR          NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# CLAYPK           NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
#
#           species group species.1 subgroup species.2 subspecies
# peptide
# TPEEEER       NaN   NaN       NaN      NaN       NaN        NaN
# HAVSEGTK      NaN   NaN       NaN      NaN       NaN        NaN
# KQELEDLTK     NaN   NaN       NaN      NaN       NaN        NaN
# TTEEAVR       NaN   NaN       NaN      NaN       NaN        NaN
# CLAYPK        NaN   NaN       NaN      NaN       NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T2_323_dig_DN_Bac1 = T2_323_dig_DN.loc[(T2_323_dig_DN['kingdom'] == 'Bacteria')]

T2_323_dig_DN_Bac2 = T2_323_dig_DN.loc[(T2_323_dig_DN['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T2_323_dig_DN_Bac1))

print('# of subkingdom = ', len(T2_323_dig_DN_Bac2))

frames = [T2_323_dig_DN_Bac1, T2_323_dig_DN_Bac2]
  
T2_323_dig_DN_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T2_323_dig_DN_Bac))

T2_323_dig_DN_Bac.head()
# Out:
# # of kingdom =  125
# # of subkingdom =  9
# # of total Bacteria peptides =  134
#                               lca superkingdom   kingdom subkingdom  \
# peptide
# VTNAELAEVLAR          Escherichia         coli  Bacteria        NaN
# SNGLSEEK      Gammaproteobacteria    bacterium  Bacteria        NaN
# VSLNKVYK                Ehrlichia   minasensis  Bacteria        NaN
# EVPQELVR              Pseudomonas     cichorii  Bacteria        NaN
# LATVLSPR      Gammaproteobacteria    bacterium  Bacteria        NaN
#
#              superphylum phylum       subphylum superclass class  \
# peptide
# VTNAELAEVLAR         NaN    NaN  Proteobacteria        NaN   NaN
# SNGLSEEK             NaN    NaN  Proteobacteria        NaN   NaN
# VSLNKVYK             NaN    NaN  Proteobacteria        NaN   NaN
# EVPQELVR             NaN    NaN  Proteobacteria        NaN   NaN
# LATVLSPR             NaN    NaN  Proteobacteria        NaN   NaN
#
#                          subclass  ... tribe subtribe genus     subgenus  \
# peptide                            ...
# VTNAELAEVLAR  Gammaproteobacteria  ...   NaN      NaN   NaN  Escherichia
# SNGLSEEK      Gammaproteobacteria  ...   NaN      NaN   NaN          NaN
# VSLNKVYK      Alphaproteobacteria  ...   NaN      NaN   NaN    Ehrlichia
# EVPQELVR      Gammaproteobacteria  ...   NaN      NaN   NaN  Pseudomonas
# LATVLSPR      Gammaproteobacteria  ...   NaN      NaN   NaN          NaN
#
#              species        group species.1             subgroup  species.2  \
# peptide
# VTNAELAEVLAR     NaN          NaN       NaN          Escherichia       coli
# SNGLSEEK         NaN          NaN       NaN  Gammaproteobacteria  bacterium
# VSLNKVYK         NaN        canis     group                  NaN  Ehrlichia
# EVPQELVR         NaN  Pseudomonas  syringae                group        NaN
# LATVLSPR         NaN          NaN       NaN  Gammaproteobacteria  bacterium
#
#                subspecies
# peptide
# VTNAELAEVLAR          NaN
# SNGLSEEK              NaN
# VSLNKVYK       minasensis
# EVPQELVR      Pseudomonas
# LATVLSPR              NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 4. T5 324 trypsin DN

# %%
# read the data into pandas dataframes
T5_324_dig_DN = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T5-324-trypsin-lca-DN.csv", index_col=0)

T5_324_dig_DN.head()
# Out:
#             lca superkingdom kingdom subkingdom superphylum phylum subphylum  \
# peptide
# KFDEETK    root          NaN     NaN        NaN         NaN    NaN       NaN
# TPEEEER    root          NaN     NaN        NaN         NaN    NaN       NaN
# HLDVDDSGK   NaN          NaN     NaN        NaN         NaN    NaN       NaN
# SPNETEER    NaN          NaN     NaN        NaN         NaN    NaN       NaN
# VVEEVVR    root          NaN     NaN        NaN         NaN    NaN       NaN
#
#           superclass class subclass  ... tribe subtribe genus subgenus  \
# peptide                              ...
# KFDEETK          NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# TPEEEER          NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# HLDVDDSGK        NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# SPNETEER         NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
# VVEEVVR          NaN   NaN      NaN  ...   NaN      NaN   NaN      NaN
#
#           species group species.1 subgroup species.2 subspecies
# peptide
# KFDEETK       NaN   NaN       NaN      NaN       NaN        NaN
# TPEEEER       NaN   NaN       NaN      NaN       NaN        NaN
# HLDVDDSGK     NaN   NaN       NaN      NaN       NaN        NaN
# SPNETEER      NaN   NaN       NaN      NaN       NaN        NaN
# VVEEVVR       NaN   NaN       NaN      NaN       NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T5_324_dig_DN_Bac1 = T5_324_dig_DN.loc[(T5_324_dig_DN['kingdom'] == 'Bacteria')]

T5_324_dig_DN_Bac2 = T5_324_dig_DN.loc[(T5_324_dig_DN['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T5_324_dig_DN_Bac1))

print('# of subkingdom = ', len(T5_324_dig_DN_Bac2))

frames = [T5_324_dig_DN_Bac1, T5_324_dig_DN_Bac2]
  
T5_324_dig_DN_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T5_324_dig_DN_Bac))

T5_324_dig_DN_Bac.head()
# Out:
# # of kingdom =  74
# # of subkingdom =  4
# # of total Bacteria peptides =  78
#                       lca   superkingdom   kingdom subkingdom superphylum  \
# peptide
# VTNAELAEVLAR  Escherichia           coli  Bacteria        NaN         NaN
# QGYSNPR       Barnesiella    viscericola  Bacteria        NaN         NaN
# FNSSLAGR      Rhodobacter        viridis  Bacteria        NaN         NaN
# WGAPAPR         Halomonas      ilicicola  Bacteria        NaN         NaN
# ANNDVPR        Candidatus  Aureabacteria  Bacteria        NaN         NaN
#
#              phylum       subphylum     superclass class             subclass  \
# peptide
# VTNAELAEVLAR    NaN  Proteobacteria            NaN   NaN  Gammaproteobacteria
# QGYSNPR         NaN   Bacteroidetes            NaN   NaN          Bacteroidia
# FNSSLAGR        NaN  Proteobacteria            NaN   NaN  Alphaproteobacteria
# WGAPAPR         NaN  Proteobacteria            NaN   NaN  Gammaproteobacteria
# ANNDVPR         NaN      Candidatus  Aureabacteria   NaN                  NaN
#
#               ... tribe subtribe genus     subgenus species group species.1  \
# peptide       ...
# VTNAELAEVLAR  ...   NaN      NaN   NaN  Escherichia     NaN   NaN       NaN
# QGYSNPR       ...   NaN      NaN   NaN  Barnesiella     NaN   NaN       NaN
# FNSSLAGR      ...   NaN      NaN   NaN  Rhodobacter     NaN   NaN       NaN
# WGAPAPR       ...   NaN      NaN   NaN    Halomonas     NaN   NaN       NaN
# ANNDVPR       ...   NaN      NaN   NaN          NaN     NaN   NaN       NaN
#
#                  subgroup    species.2 subspecies
# peptide
# VTNAELAEVLAR  Escherichia         coli        NaN
# QGYSNPR       Barnesiella  viscericola        NaN
# FNSSLAGR      Rhodobacter      viridis        NaN
# WGAPAPR         Halomonas    ilicicola        NaN
# ANNDVPR               NaN          NaN        NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 5. T12 325 trypsin DN

# %%
# read the data into pandas dataframes
T12_325_dig_DN = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T12-325-trypsin-lca-DN.csv", index_col=0)

T12_325_dig_DN.head()
# Out:
#                     lca superkingdom    kingdom subkingdom superphylum phylum  \
# peptide
# SPPALALK            NaN          NaN        NaN        NaN         NaN    NaN
# KNEAEELK           root          NaN        NaN        NaN         NaN    NaN
# FLGNLLTR       Bacteria     Bacteria        NaN        NaN         NaN    NaN
# DEETKLSK   Biomphalaria     glabrata  Eukaryota    Metazoa         NaN    NaN
# HLDVDDSGK           NaN          NaN        NaN        NaN         NaN    NaN
#
#           subphylum superclass class    subclass  ... tribe subtribe genus  \
# peptide                                           ...
# SPPALALK        NaN        NaN   NaN         NaN  ...   NaN      NaN   NaN
# KNEAEELK        NaN        NaN   NaN         NaN  ...   NaN      NaN   NaN
# FLGNLLTR        NaN        NaN   NaN         NaN  ...   NaN      NaN   NaN
# DEETKLSK   Mollusca        NaN   NaN  Gastropoda  ...   NaN      NaN   NaN
# HLDVDDSGK       NaN        NaN   NaN         NaN  ...   NaN      NaN   NaN
#
#                subgenus species group species.1      subgroup species.2  \
# peptide
# SPPALALK            NaN     NaN   NaN       NaN           NaN       NaN
# KNEAEELK            NaN     NaN   NaN       NaN           NaN       NaN
# FLGNLLTR            NaN     NaN   NaN       NaN           NaN       NaN
# DEETKLSK   Biomphalaria     NaN   NaN       NaN  Biomphalaria  glabrata
# HLDVDDSGK           NaN     NaN   NaN       NaN           NaN       NaN
#
#           subspecies
# peptide
# SPPALALK         NaN
# KNEAEELK         NaN
# FLGNLLTR         NaN
# DEETKLSK         NaN
# HLDVDDSGK        NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T12_325_dig_DN_Bac1 = T12_325_dig_DN.loc[(T12_325_dig_DN['kingdom'] == 'Bacteria')]

T12_325_dig_DN_Bac2 = T12_325_dig_DN.loc[(T12_325_dig_DN['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T12_325_dig_DN_Bac1))

print('# of subkingdom = ', len(T12_325_dig_DN_Bac2))

frames = [T12_325_dig_DN_Bac1, T12_325_dig_DN_Bac2]
  
T12_325_dig_DN_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T12_325_dig_DN_Bac))

T12_325_dig_DN_Bac.head()
# Out:
# # of kingdom =  135
# # of subkingdom =  8
# # of total Bacteria peptides =  143
#                               lca    superkingdom   kingdom subkingdom  \
# peptide
# VTNAELAEVLAR          Escherichia            coli  Bacteria        NaN
# VSNDTAENR           Marinirhabdus  gelatinilytica  Bacteria        NaN
# FFLFDDVR          Verrucomicrobia       bacterium  Bacteria        NaN
# TNFVNPK          Chryseobacterium  arthrosphaerae  Bacteria        NaN
# LATVLSPR      Gammaproteobacteria       bacterium  Bacteria        NaN
#
#              superphylum phylum        subphylum superclass class  \
# peptide
# VTNAELAEVLAR         NaN    NaN   Proteobacteria        NaN   NaN
# VSNDTAENR            NaN    NaN    Bacteroidetes        NaN   NaN
# FFLFDDVR             NaN    NaN  Verrucomicrobia        NaN   NaN
# TNFVNPK              NaN    NaN    Bacteroidetes        NaN   NaN
# LATVLSPR             NaN    NaN   Proteobacteria        NaN   NaN
#
#                          subclass  ... tribe subtribe genus          subgenus  \
# peptide                            ...
# VTNAELAEVLAR  Gammaproteobacteria  ...   NaN      NaN   NaN       Escherichia
# VSNDTAENR          Flavobacteriia  ...   NaN      NaN   NaN     Marinirhabdus
# FFLFDDVR                      NaN  ...   NaN      NaN   NaN               NaN
# TNFVNPK            Flavobacteriia  ...   NaN      NaN   NaN  Chryseobacterium
# LATVLSPR      Gammaproteobacteria  ...   NaN      NaN   NaN               NaN
#
#              species group species.1             subgroup       species.2  \
# peptide
# VTNAELAEVLAR     NaN   NaN       NaN          Escherichia            coli
# VSNDTAENR        NaN   NaN       NaN        Marinirhabdus  gelatinilytica
# FFLFDDVR         NaN   NaN       NaN      Verrucomicrobia       bacterium
# TNFVNPK          NaN   NaN       NaN     Chryseobacterium  arthrosphaerae
# LATVLSPR         NaN   NaN       NaN  Gammaproteobacteria       bacterium
#
#              subspecies
# peptide
# VTNAELAEVLAR        NaN
# VSNDTAENR           NaN
# FFLFDDVR            NaN
# TNFVNPK             NaN
# LATVLSPR            NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 6. T12 325 trypsin DB

# %%
# read the data into pandas dataframes
T12_325_dig_DB = pd.read_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/cleaned/T12-325-trypsin-lca-DB.csv", index_col=0)

T12_325_dig_DB.head()
# Out:
#                                  lca superkingdom kingdom subkingdom  \
# peptide
# LPQVEGTGGDVQPSQDLVR             root          NaN     NaN        NaN
# VLGQNEAVDAVSNALR                root          NaN     NaN        NaN
# ALDLLDEAASSLR                   root          NaN     NaN        NaN
# DVPGTGNEFVGDFR       Bacillariophyta    Eukaryota     NaN        NaN
# VTDAELAEVLAR                    root          NaN     NaN        NaN
#
#                      superphylum           phylum subphylum superclass class  \
# peptide
# LPQVEGTGGDVQPSQDLVR          NaN              NaN       NaN        NaN   NaN
# VLGQNEAVDAVSNALR             NaN              NaN       NaN        NaN   NaN
# ALDLLDEAASSLR                NaN              NaN       NaN        NaN   NaN
# DVPGTGNEFVGDFR               NaN  Bacillariophyta       NaN        NaN   NaN
# VTDAELAEVLAR                 NaN              NaN       NaN        NaN   NaN
#
#                     subclass  ... tribe subtribe genus subgenus species group  \
# peptide                       ...
# LPQVEGTGGDVQPSQDLVR      NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# VLGQNEAVDAVSNALR         NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# ALDLLDEAASSLR            NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# DVPGTGNEFVGDFR           NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
# VTDAELAEVLAR             NaN  ...   NaN      NaN   NaN      NaN     NaN   NaN
#
#                     species.1 subgroup species.2 subspecies
# peptide
# LPQVEGTGGDVQPSQDLVR       NaN      NaN       NaN        NaN
# VLGQNEAVDAVSNALR          NaN      NaN       NaN        NaN
# ALDLLDEAASSLR             NaN      NaN       NaN        NaN
# DVPGTGNEFVGDFR            NaN      NaN       NaN        NaN
# VTDAELAEVLAR              NaN      NaN       NaN        NaN
#
# [5 rows x 29 columns]

# %%
# Take just the bacterial peptides

# keep only the rows where kingdom = Bacteria

T12_325_dig_DB_Bac1 = T12_325_dig_DB.loc[(T12_325_dig_DB['kingdom'] == 'Bacteria')]

T12_325_dig_DB_Bac2 = T12_325_dig_DB.loc[(T12_325_dig_DB['subkingdom'] == 'Bacteria')]

print('# of kingdom = ', len(T12_325_dig_DB_Bac1))

print('# of subkingdom = ', len(T12_325_dig_DB_Bac2))

frames = [T12_325_dig_DB_Bac1, T12_325_dig_DB_Bac2]
  
T12_325_dig_DB_Bac = pd.concat(frames)

print('# of total Bacteria peptides = ', len(T12_325_dig_DB_Bac))

T12_325_dig_DB_Bac.head()
# Out:
# # of kingdom =  1
# # of subkingdom =  1
# # of total Bacteria peptides =  2
#                    lca   superkingdom    kingdom subkingdom  superphylum  \
# peptide
# NDEALAFLR  Chloroflexi      bacterium   Bacteria        NaN          NaN
# DKFDEETK    Candidatus  Cloacimonetes  bacterium   Bacteria          NaN
#
#           phylum    subphylum  superclass          class subclass  ... tribe  \
# peptide                                                            ...
# NDEALAFLR    NaN  Chloroflexi         NaN            NaN      NaN  ...   NaN
# DKFDEETK     NaN          NaN  Candidatus  Cloacimonetes      NaN  ...   NaN
#
#           subtribe genus subgenus species group species.1     subgroup  \
# peptide
# NDEALAFLR      NaN   NaN      NaN     NaN   NaN       NaN  Chloroflexi
# DKFDEETK       NaN   NaN      NaN     NaN   NaN       NaN          NaN
#
#            species.2  subspecies
# peptide
# NDEALAFLR  bacterium         NaN
# DKFDEETK         NaN  Candidatus
#
# [2 rows x 29 columns]

# %% [markdown]
# ### Combining all bacterial peptide results

# %%
frames = [T0_322_dig_DB_Bac, T0_322_dig_DN_Bac, T2_323_dig_DN_Bac, \
          T5_324_dig_DN_Bac, T12_325_dig_DN_Bac, T12_325_dig_DB_Bac]
  
combo_Bac = pd.concat(frames)

combo_Bac_dd = pd.DataFrame.drop_duplicates(combo_Bac)

print('# of total Bacteria peptides = ', len(combo_Bac))
print('# of nonredudant Bacteria peptides = ', len(combo_Bac_dd))

combo_Bac.head()
# Out:
# # of total Bacteria peptides =  471
# # of nonredudant Bacteria peptides =  342
#                        lca   superkingdom   kingdom subkingdom superphylum  \
# peptide
# QGYSNPR        Barnesiella    viscericola  Bacteria        NaN         NaN
# DSPPALALK  Verrucomicrobia      bacterium  Bacteria        NaN         NaN
# SVDPYDR       Streptomyces  violaceoruber  Bacteria        NaN         NaN
# NDEALAFLR      Chloroflexi      bacterium  Bacteria        NaN         NaN
# SGDCTQER     Myxococcaceae      bacterium  Bacteria        NaN         NaN
#
#           phylum        subphylum     superclass         class  \
# peptide
# QGYSNPR      NaN    Bacteroidetes            NaN           NaN
# DSPPALALK    NaN  Verrucomicrobia            NaN           NaN
# SVDPYDR      NaN   Actinobacteria            NaN           NaN
# NDEALAFLR    NaN      Chloroflexi            NaN           NaN
# SGDCTQER     NaN   Proteobacteria  delta/epsilon  subdivisions
#
#                  subclass  ...          tribe subtribe genus      subgenus  \
# peptide                    ...
# QGYSNPR       Bacteroidia  ...            NaN      NaN   NaN   Barnesiella
# DSPPALALK             NaN  ...            NaN      NaN   NaN           NaN
# SVDPYDR    Actinobacteria  ...            NaN      NaN   NaN  Streptomyces
# NDEALAFLR             NaN  ...            NaN      NaN   NaN           NaN
# SGDCTQER              NaN  ...  Myxococcaceae      NaN   NaN           NaN
#
#           species group species.1         subgroup      species.2 subspecies
# peptide
# QGYSNPR       NaN   NaN       NaN      Barnesiella    viscericola        NaN
# DSPPALALK     NaN   NaN       NaN  Verrucomicrobia      bacterium        NaN
# SVDPYDR       NaN   NaN       NaN     Streptomyces  violaceoruber        NaN
# NDEALAFLR     NaN   NaN       NaN      Chloroflexi      bacterium        NaN
# SGDCTQER      NaN   NaN       NaN              NaN  Myxococcaceae  bacterium
#
# [5 rows x 29 columns]

# %%
# keep only peptide column

combo_Bac_dd.reset_index(inplace=True)

bac_pep = combo_Bac_dd[["peptide"]]

# write altered dataframe to new txt file
# used header and index parameters to get rid of 'Peptide' header and the indexing
bac_pep.to_csv("/home/millieginty/Documents/git-repos/rot-mayer/analyses/unipept/lca/nonredundant_Bac_peptides.txt", header=False, index=False)

bac_pep.head()
# Out:
#      peptide
# 0    QGYSNPR
# 1  DSPPALALK
# 2    SVDPYDR
# 3  NDEALAFLR
# 4   SGDCTQER

# %% [markdown]
# ### 251 peptides (73%) have at least one GO-term assigned to them after running nonredudant peptides through UniPept
#
# ![GO term hierarchy](https://github.com/MeganEDuffy/rot-mayer/blob/master/analyses/unipept/GO-terms/nonredundant_bac_go_biological_process.png)

# %% [markdown]
# ## Plotting bacterial GO terms using Seaborn heatmap
#
# ### This will be Figure 6b in the algae rot manuscript
# ### Originally this code was in another notebook, `GO-terms-diatom-bac`

# %%
# rearranged and condensed the csv manually in Libre Calc
# read in new csv:

cc = pd.read_csv("/home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/unipept/GO/plotting/BY_CC_GO_sorted.csv", index_col=0)

cc.head()
# Out:
#                                 Time 0 small   T0 large  T24 small  \
# GO Cellular Component
# integral component of membrane     41.520468  48.837209  48.120301
# cytoplasm                          28.654971  23.255814  22.932331
# plasma membrane                    18.128655  13.953488  18.421053
# nucleus                             7.017544   6.976744   6.766917
# ribosome                            2.339181   3.488372   2.255639
#
#                                 Time 24 large
# GO Cellular Component
# integral component of membrane      45.360825
# cytoplasm                           22.680412
# plasma membrane                     19.587629
# nucleus                              6.185567
# ribosome                             4.123711

# %%
sns.set(font_scale=1.2)  

fig, ax = plt.subplots(figsize=(6,12))

ax = sns.heatmap(cc, cmap="BuPu", annot=True, linecolor = 'grey', linewidths=.01, \
                square=False, cbar_kws={'label': '% of all cellular component GO terms'}, label='big')

ax.set_ylabel('')

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)
    

for item in ax.get_xticklabels():
    item.set_rotation(45)
    
plt.title("% of cellular component GO terms", size = 16, pad = 20)
# Out:
# Text(0.5, 1.0, '% of cellular component GO terms')
