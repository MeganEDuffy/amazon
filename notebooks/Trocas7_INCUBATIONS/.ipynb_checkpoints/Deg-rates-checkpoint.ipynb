# %% [markdown]
# # Plotting particulate protein degradation and bulk respiration rates in Trocas7 incbubations (April 2019, high water).
#
# ## Have BOD (biological oxygen demand) respiration rates for all 24 hr incubations at all four stations.
#
# ## Protein degradation rates for 0.3-0.7 um and >0.7 size fractions by Lowry assay

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from functools import reduce

# %%
cd /home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/deg-rates/
# Out:
# /home/millieginty/Documents/git-repos/amazon/analyses/T7-incubations/deg-rates

# %%
rates = pd.read_csv('deg-rates.csv')

rates.head()
# Out:
#         Station   Bulk  BOD error  0.3-0.7 um rate  small error p  \
# 0  Macapa North  0.055      0.005            1.418           0.10
# 1  Macapa South  0.040      0.004            1.487           0.15
# 2      Baylique  0.055      0.009            1.016           0.13
# 3        Chaves  0.048      0.007            0.760           0.09
#
#    >0.7 um rate  large error p  small deg c  small error c  large deg c  \
# 0         0.338           0.18        0.752           0.14        0.179
# 1         0.384           0.21        0.788           0.24        0.203
# 2         2.666           0.32        0.539           0.15        1.413
# 3         1.747           0.25        0.403           0.23        0.926
#
#    large error c  0.3-0.7 um conc.  small error init  >0.7 um conc.  \
# 0           0.09             1.534              0.10          0.597
# 1           0.11             1.674              0.15          0.788
# 2           0.14             1.182              0.13          3.070
# 3           0.16             1.021              0.09          2.047
#
#    large error init
# 0              0.18
# 1              0.21
# 2              0.32
# 3              0.25

# %%
fig, axes = plt.subplots(figsize=(10, 8),nrows=2, ncols=2, sharex = True)
plt.tight_layout()

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=2, hspace=0.2)

labels = ['Macapa North', 'Macapa South', 'Baylique', 'Chaves']

# Plot BOD respiration rates with errors
rates.plot.bar(ax = axes[0,0], x='Station', y='Bulk', yerr='BOD error', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#ffffff')
axes[0,0].set_ylabel('Bulk respiration rate (mg C/L/day)')
axes[0,0].set_title('a. Bulk respiration rate', size = 14, loc = 'left')

axes[0,1].set_yticklabels('Bulk', color="white")
axes[0,1].spines['bottom'].set_color('white')
axes[0,1].spines['top'].set_color('white') 
axes[0,1].spines['right'].set_color('white')
axes[0,1].spines['left'].set_color('white')
axes[0,1].tick_params(axis='x', colors='white')
axes[0,1].tick_params(axis='y', colors='white')

# Plot small size fraction degradation
rates.plot.bar(ax = axes[1,0], x='Station', y='0.3-0.7 um rate', yerr='small error p', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#999999')
axes[1,0].set_ylabel('Small particle deg. rate (mg protein/L/day)')
axes[1,0].set_xlabel('')
axes[1,0].set_xticklabels(labels, rotation = 40)
axes[1,0].set_title('b. Small particle protein deg, rate', size = 14, loc = 'left')

# Plot small size fraction degradation
rates.plot.bar(ax = axes[1,1], x='Station', y='>0.7 um rate', yerr='large error p', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#999999')
axes[1,1].set_ylabel('Large particle deg. rate (mg protein/L/day)')
axes[1,1].set_xlabel('')
axes[1,1].set_xticklabels(labels, rotation = 40)
axes[1,1].set_title('c. Large particle protein deg, rate', size = 14, loc = 'left')

#axes[0,0].set_title('a) Biological oxygen demand respiration rate', fontsize = 14, loc='left')

plt.tight_layout()
#plt.savefig('protein-deg.png')

# %% [markdown]
# ## Plot the initital protein concentrations - in the mix

# %%
fig, axes = plt.subplots(figsize=(10, 10),nrows=3, ncols=2, sharex = True)
plt.tight_layout()

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=2, hspace=0.2)

labels = ['Macapa North', 'Macapa South', 'Baylique', 'Chaves']

# Plot BOD respiration rates with errors
rates.plot.bar(ax = axes[0,0], x='Station', y='Bulk', yerr='BOD error', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#ffffff')
axes[0,0].set_ylabel('Bulk respiration rate (mg C/L/day)')
axes[0,0].set_title('a. Bulk respiration rate', size = 14, loc = 'left')

axes[0,1].set_yticklabels('Bulk', color="white")
axes[0,1].spines['bottom'].set_color('white')
axes[0,1].spines['top'].set_color('white') 
axes[0,1].spines['right'].set_color('white')
axes[0,1].spines['left'].set_color('white')
axes[0,1].tick_params(axis='x', colors='white')
axes[0,1].tick_params(axis='y', colors='white')

# Plot initital small particle protein concentrations
rates.plot.bar(ax = axes[1,0], x='Station', y='0.3-0.7 um conc.', yerr='small error init', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#ffffff', fill = False, hatch = '///')
axes[1,0].set_ylabel('Protein conc (mg/L)')
axes[1,0].set_title('b. Initial small particle protein conc.', size = 14, loc = 'left')

# Plot initital large particle protein concentrations
rates.plot.bar(ax = axes[1,1], x='Station', y='>0.7 um conc.', yerr='large error init', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#ffffff', fill = False, hatch = '///')
axes[1,1].set_ylabel('Protein conc (mg/L)')
axes[1,1].set_title('c. Initial large particle protein conc.', size = 14, loc = 'left')

# Plot small size fraction degradation
rates.plot.bar(ax = axes[2,0], x='Station', y='0.3-0.7 um rate', yerr='small error p', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#999999')
axes[2,0].set_ylabel('Small particle deg. rate (mg protein/L/day)')
axes[2,0].set_xlabel('')
axes[2,0].set_xticklabels(labels, rotation = 40)
axes[2,0].set_title('d. Small particle protein deg, rate', size = 14, loc = 'left')

# Plot small size fraction degradation
rates.plot.bar(ax = axes[2,1], x='Station', y='>0.7 um rate', yerr='large error p', \
               capsize=5, rot = 45, edgecolor = 'black', color = '#999999')
axes[2,1].set_ylabel('Large particle deg. rate (mg protein/L/day)')
axes[2,1].set_xlabel('')
axes[2,1].set_xticklabels(labels, rotation = 40)
axes[2,1].set_title('e. Large particle protein deg, rate', size = 14, loc = 'left')

#axes[0,0].set_title('a) Biological oxygen demand respiration rate', fontsize = 14, loc='left')

plt.tight_layout()
#plt.savefig('protein-deg.png')
